# %% [markdown]
# ### - In this example, we'll be working with data from Kaggle.com, about netflix originals shows.

# %%
# Before we analyze anything, we need to import pandas
import pandas as pd

# %% [markdown]
# - we need to load our csv file

# %%
df = pd.read_csv("NetflixOriginals.csv", encoding='ISO-8859-1')

# %% [markdown]
# - lets examine the first 10 rows

# %%
df.head(10)
# Out:
#                              Title                    Genre  Unnamed: 2  \
# 0                  Enter the Anime              Documentary         NaN
# 1                      Dark Forces                 Thriller         NaN
# 2                          The App    Science fiction/Drama         NaN
# 3                   The Open House          Horror thriller         NaN
# 4                      Kaali Khuhi                  Mystery         NaN
# 5                            Drive                   Action         NaN
# 6                Leyla Everlasting                   Comedy         NaN
# 7  The Last Days of American Crime      Heist film/Thriller         NaN
# 8                          Paradox  Musical/Western/Fantasy         NaN
# 9               Sardar Ka Grandson                   Comedy         NaN
#
#    Unnamed: 3  Unnamed: 4  Date_of_film          Language
# 0         NaN         NaN          2019  English/Japanese
# 1         NaN         NaN          2020           Spanish
# ...

# %% [markdown]
# - lets select all the comedy shows

# %%
df[df.Genre == "Comedy"]
# Out:
#                                                 Title   Genre  Unnamed: 2  \
# 6                                   Leyla Everlasting  Comedy         NaN
# 9                                  Sardar Ka Grandson  Comedy         NaN
# 18                          What Happened to Mr. Cha?  Comedy         NaN
# 22                                         Sextuplets  Comedy         NaN
# 27                                   Seriously Single  Comedy         NaN
# 28              The Misadventures of Hedi and Cokeman  Comedy         NaN
# 29                                   5 Star Christmas  Comedy         NaN
# 33   Porta dos Fundos: The First Temptation of Christ  Comedy         NaN
# 35                                        The Players  Comedy         NaN
# 47                                        Take the 10  Comedy         NaN
# 48                                     The Main Event  Comedy         NaN
# 54                                      Airplane Mode  Comedy         NaN
# ...

# %% [markdown]
# - let's select all the comedy shows as previously but with french language

# %%
df[(df.Genre == "Comedy") & (df.Language == "French")]
# Out:
#                                     Title   Genre  Unnamed: 2  Unnamed: 3  \
# 28  The Misadventures of Hedi and Cokeman  Comedy         NaN         NaN
# 85                         Back to School  Comedy         NaN         NaN
#
#     Unnamed: 4  Date_of_film Language
# 28         NaN          2021   French
# 85         NaN          2019   French
